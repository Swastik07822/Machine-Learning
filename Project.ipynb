# %% [markdown]
# <a href="https://colab.research.google.com/github/Swastik07822/Machine-Learning/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib

# %%
# !pip install scikit-learn

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn

import seaborn as sns
plt.rcParams['figure.figsize'] = (10, 10)

# %%
sklearn.__version__
# Out:
# '1.2.2'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv(r'/dataset.csv')

# %%
data.drop('id', axis=1, inplace=True)

# %%
data
# Out:
#        gender    age  hypertension  heart_disease ever_married      work_type  \
# 0        Male  19.17             0              1          Yes  Self-employed
# 1      Female  22.07             0              1          Yes        Private
# 2        Male  48.56             0              0           No       Govt_job
# 3        Male  20.96             0              1           No        Private
# 4        Male  22.94             0              0          Yes       Govt_job
# ...       ...    ...           ...            ...          ...            ...
# 19994  Female  25.77             0              0          Yes        Private
# 19995    Male  58.41             0              0           No       children
# 19996    Male  54.63             0              0           No  Self-employed
# 19997  Female  14.01             0              0          Yes  Self-employed
# 19998    Male  58.06             0              0           No       children
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             19999 non-null  object
#  1   age                19999 non-null  object
#  2   hypertension       19999 non-null  int64
#  3   heart_disease      19999 non-null  int64
#  4   ever_married       19999 non-null  object
#  5   work_type          19999 non-null  object
#  6   Residence_type     19999 non-null  object
#  7   avg_glucose_level  19999 non-null  float64
#  8   bmi                19461 non-null  object
#  9   smoking_status     19999 non-null  object
#  10  stroke             19999 non-null  int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.7+ MB

# %%
data['age'] = pd.to_numeric(data['age'], errors='coerce')

# %%
data['age'] = data['age'].round()

# %%
data['age'] = data['age'].astype('float64')

# %%
data['age'] = pd.to_numeric(data['age'], errors='coerce')

# %%
data['bmi'] = pd.to_numeric(data['bmi'], errors='coerce')
data['bmi'] = data['bmi'].astype('float64')

# %%
data
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 0        Male  19.0             0              1          Yes  Self-employed
# 1      Female  22.0             0              1          Yes        Private
# 2        Male  49.0             0              0           No       Govt_job
# 3        Male  21.0             0              1           No        Private
# 4        Male  23.0             0              0          Yes       Govt_job
# ...       ...   ...           ...            ...          ...            ...
# 19994  Female  26.0             0              0          Yes        Private
# 19995    Male  58.0             0              0           No       children
# 19996    Male  55.0             0              0           No  Self-employed
# 19997  Female  14.0             0              0          Yes  Self-employed
# 19998    Male  58.0             0              0           No       children
#
# ...

# %%
# Fill NaN values in BMI column with mean
data["bmi"] = data["bmi"].fillna(data["bmi"].mean())

# %%
data.iloc[2260]
# Out:
# gender                          Male
# age                             56.0
# hypertension                       0
# heart_disease                      0
# ever_married                      No
# work_type                   Govt_job
# Residence_type                 Urban
# avg_glucose_level             156.16
# bmi                             23.5
# smoking_status       formerly smoked
# stroke                             0
# Name: 2260, dtype: object

# %%
data.isnull()
# Out:
#        gender    age  hypertension  heart_disease  ever_married  work_type  \
# 0       False  False         False          False         False      False
# 1       False  False         False          False         False      False
# 2       False  False         False          False         False      False
# 3       False  False         False          False         False      False
# 4       False  False         False          False         False      False
# ...       ...    ...           ...            ...           ...        ...
# 19994   False  False         False          False         False      False
# 19995   False  False         False          False         False      False
# 19996   False  False         False          False         False      False
# 19997   False  False         False          False         False      False
# 19998   False  False         False          False         False      False
#
# ...

# %%
data[data.isnull().any(axis=1)]
# Out:
#       gender  age  hypertension  heart_disease ever_married      work_type  \
# 15991   Male  NaN             0              0           No       Govt_job
# 18952   Male  NaN             0              1          Yes  Self-employed
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 15991          Rural             131.00  21.1          Unknown       0
# 18952          Urban             131.16  40.2  formerly smoked       0

# %%
data.drop(index=[15991, 18952], axis=0, inplace=True)

# %%
data.iloc[18952]
# Out:
# gender                  Male
# age                      8.0
# hypertension               0
# heart_disease              1
# ever_married              No
# work_type            Private
# Residence_type         Rural
# avg_glucose_level      68.67
# bmi                     47.0
# smoking_status        smokes
# stroke                     0
# Name: 18954, dtype: object

# %%
# !pip install pandas-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv('/content/drive/MyDrive/healthcare-dataset-stroke-data.csv')
profile = ProfileReport(df, title="Profiling Report")

# %% [markdown]
# ## **Exploratory data analysis**

# %%
data.tail(10)
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 19989  Female   2.0             0              0           No  Self-employed
# 19990    Male  54.0             0              1           No       Govt_job
# 19991    Male  52.0             0              0          Yes  Self-employed
# 19992    Male  60.0             0              0          Yes       Govt_job
# 19993    Male  16.0             0              0          Yes       Govt_job
# 19994  Female  26.0             0              0          Yes        Private
# 19995    Male  58.0             0              0           No       children
# 19996    Male  55.0             0              0           No  Self-employed
# 19997  Female  14.0             0              0          Yes  Self-employed
# 19998    Male  58.0             0              0           No       children
#
#       Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# ...

# %%
data['smoking_status'].unique()
# Out:
# array(['Unknown', 'never smoked', 'smokes', 'formerly smoked'],
#       dtype=object)

# %%
j = 0

for i in data['work_type']:

  #print(i)

  j += 1

  if i == 'children':

    ans = j

    print(ans)

    break
# Out:
# 15

# %%
data
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 0        Male  19.0             0              1          Yes  Self-employed
# 1      Female  22.0             0              1          Yes        Private
# 2        Male  49.0             0              0           No       Govt_job
# 3        Male  21.0             0              1           No        Private
# 4        Male  23.0             0              0          Yes       Govt_job
# ...       ...   ...           ...            ...          ...            ...
# 19994  Female  26.0             0              0          Yes        Private
# 19995    Male  58.0             0              0           No       children
# 19996    Male  55.0             0              0           No  Self-employed
# 19997  Female  14.0             0              0          Yes  Self-employed
# 19998    Male  58.0             0              0           No       children
#
# ...

# %%
data.iloc[162]
# Out:
# gender                        Female
# age                             15.0
# hypertension                       0
# heart_disease                      0
# ever_married                      No
# work_type                    Private
# Residence_type                 Urban
# avg_glucose_level             116.65
# bmi                             24.5
# smoking_status       formerly smoked
# stroke                             0
# Name: 162, dtype: object

# %%
data['Residence_type'].unique()
# Out:
# array(['Rural', 'Urban'], dtype=object)

# %%
data['work_type'].unique()
# Out:
# array(['Self-employed', 'Private', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %%
data.shape
# Out:
# (19997, 11)

# %%
data.info
# Out:
# <bound method DataFrame.info of        gender   age  hypertension  heart_disease ever_married      work_type  \
# 0        Male  19.0             0              1          Yes  Self-employed
# 1      Female  22.0             0              1          Yes        Private
# 2        Male  49.0             0              0           No       Govt_job
# 3        Male  21.0             0              1           No        Private
# 4        Male  23.0             0              0          Yes       Govt_job
# ...       ...   ...           ...            ...          ...            ...
# 19994  Female  26.0             0              0          Yes        Private
# 19995    Male  58.0             0              0           No       children
# 19996    Male  55.0             0              0           No  Self-employed
# 19997  Female  14.0             0              0          Yes  Self-employed
# 19998    Male  58.0             0              0           No       children
#
# ...

# %%
data.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# #**fill Null Values**

# %%
data['bmi'].value_counts()
# Out:
# bmi
# 26.176444    543
# 27.400000    215
# 27.300000    211
# 27.200000    186
# 27.500000    183
#             ...
# 42.500000      3
# 53.500000      3
# 41.900000      2
# 44.200000      2
# 44.100000      2
# Name: count, Length: 345, dtype: int64

# %%
data['bmi'].describe()
# Out:
# count    19997.000000
# mean        26.175997
# std          6.650920
# min         11.300000
# 25%         21.300000
# 50%         26.176444
# 75%         30.200000
# max         53.500000
# Name: bmi, dtype: float64

# %%
data.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
data
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 0        Male  19.0             0              1          Yes  Self-employed
# 1      Female  22.0             0              1          Yes        Private
# 2        Male  49.0             0              0           No       Govt_job
# 3        Male  21.0             0              1           No        Private
# 4        Male  23.0             0              0          Yes       Govt_job
# ...       ...   ...           ...            ...          ...            ...
# 19994  Female  26.0             0              0          Yes        Private
# 19995    Male  58.0             0              0           No       children
# 19996    Male  55.0             0              0           No  Self-employed
# 19997  Female  14.0             0              0          Yes  Self-employed
# 19998    Male  58.0             0              0           No       children
#
# ...

# %%
data.iloc[162]
# Out:
# gender                        Female
# age                             15.0
# hypertension                       0
# heart_disease                      0
# ever_married                      No
# work_type                    Private
# Residence_type                 Urban
# avg_glucose_level             116.65
# bmi                             24.5
# smoking_status       formerly smoked
# stroke                             0
# Name: 162, dtype: object

# %% [markdown]
# # **Remove Outlier**

# %%
set(data['work_type'])
# Out:
# {'Govt_job', 'Never_worked', 'Private', 'Self-employed', 'children'}

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 10), dpi=800, facecolor='w', edgecolor='k')

# %%
data.plot(kind='box')
plt.show()

# %%
data.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  19.0             0              1          Yes  Self-employed
# 1  Female  22.0             0              1          Yes        Private
# 2    Male  49.0             0              0           No       Govt_job
# 3    Male  21.0             0              1           No        Private
# 4    Male  23.0             0              0          Yes       Govt_job
#
#   Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 0          Rural             116.54  27.5        Unknown       0
# 1          Urban             111.15  26.1   never smoked       0
# 2          Rural             154.05  17.7        Unknown       0
# 3          Urban              68.86  19.1   never smoked       0
# 4          Urban             115.05  28.2         smokes       0

# %%
data.shape
# Out:
# (19997, 11)

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
gender=enc.fit_transform(data['gender'])
smoking_status=enc.fit_transform(data['smoking_status'])
print(gender,smoking_status)
# Out:
# [1 0 1 ... 1 0 1] [0 2 0 ... 2 2 0]

# %%
work_type=enc.fit_transform(data['work_type'])
Residence_type=enc.fit_transform(data['Residence_type'])
ever_married=enc.fit_transform(data['ever_married'])
data['work_type']=work_type
print(set(work_type))
# Out:
# {0, 1, 2, 3, 4}

# %%
data['ever_married']=ever_married
data['Residence_type']=Residence_type
data['smoking_status']=smoking_status
data['gender']=gender

# %%
data
# Out:
#        gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0           1  19.0             0              1             1          3
# 1           0  22.0             0              1             1          2
# 2           1  49.0             0              0             0          0
# 3           1  21.0             0              1             0          2
# 4           1  23.0             0              0             1          0
# ...       ...   ...           ...            ...           ...        ...
# 19994       0  26.0             0              0             1          2
# 19995       1  58.0             0              0             0          4
# 19996       1  55.0             0              0             0          3
# 19997       0  14.0             0              0             1          3
# 19998       1  58.0             0              0             0          4
#
#        Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
data.iloc[162]
# Out:
# gender                 0.00
# age                   15.00
# hypertension           0.00
# heart_disease          0.00
# ever_married           0.00
# work_type              2.00
# Residence_type         1.00
# avg_glucose_level    116.65
# bmi                   24.50
# smoking_status         1.00
# stroke                 0.00
# Name: 162, dtype: float64

# %%
data.iloc[145]
# Out:
# gender                 1.00
# age                   77.00
# hypertension           0.00
# heart_disease          1.00
# ever_married           1.00
# work_type              3.00
# Residence_type         0.00
# avg_glucose_level    228.89
# bmi                   27.90
# smoking_status         1.00
# stroke                 0.00
# Name: 145, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19997 entries, 0 to 19998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             19997 non-null  int64
#  1   age                19997 non-null  float64
#  2   hypertension       19997 non-null  int64
#  3   heart_disease      19997 non-null  int64
#  4   ever_married       19997 non-null  int64
#  5   work_type          19997 non-null  int64
#  6   Residence_type     19997 non-null  int64
#  7   avg_glucose_level  19997 non-null  float64
#  8   bmi                19997 non-null  float64
#  9   smoking_status     19997 non-null  int64
#  10  stroke             19997 non-null  int64
# dtypes: float64(3), int64(8)
# memory usage: 1.8 MB

# %% [markdown]
# # **Splitting the data for train and test**
#
# X ---train_X,test_X 80/20
# Y ---train_Y,test_Y

# %%
X=data.drop('stroke',axis=1)
X.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  19.0             0              1             1          3
# 1       0  22.0             0              1             1          2
# 2       1  49.0             0              0             0          0
# 3       1  21.0             0              1             0          2
# 4       1  23.0             0              0             1          0
#
#    Residence_type  avg_glucose_level   bmi  smoking_status
# 0               0             116.54  27.5               0
# 1               1             111.15  26.1               2
# 2               0             154.05  17.7               0
# 3               1              68.86  19.1               2
# 4               1             115.05  28.2               3

# %%
Y=data['stroke']
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 19994    0
# 19995    0
# 19996    0
# 19997    0
# 19998    0
# Name: stroke, Length: 19997, dtype: int64

# %%
import sklearn
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.2,random_state=10)
X_train
# Out:
#        gender   age  hypertension  heart_disease  ever_married  work_type  \
# 2892        0  19.0             0              0             0          4
# 18643       1  21.0             0              0             1          0
# 5409        0   7.0             0              0             0          2
# 8942        1  16.0             0              0             0          4
# 8681        1  20.0             0              0             1          2
# ...       ...   ...           ...            ...           ...        ...
# 9372        0  53.0             0              0             1          2
# 7291        1  53.0             0              0             0          2
# 17729       1  42.0             0              0             0          2
# 7293        0  76.0             0              0             0          2
# 17674       1  41.0             0              0             1          0
#
#        Residence_type  avg_glucose_level        bmi  smoking_status
# ...

# %%
sklearn.__version__
# Out:
# '1.2.2'

# %%
Y_train
# Out:
# 2892     0
# 18643    0
# 5409     0
# 8942     0
# 8681     0
#         ..
# 9372     0
# 7291     0
# 17729    0
# 7293     1
# 17674    0
# Name: stroke, Length: 15997, dtype: int64

# %%
X_test
# Out:
#        gender   age  hypertension  heart_disease  ever_married  work_type  \
# 17236       0   3.0             1              0             1          0
# 18748       1  38.0             0              0             1          3
# 15002       0  58.0             0              0             1          2
# 13962       1   3.0             0              0             0          4
# 6916        0  62.0             1              0             1          0
# ...       ...   ...           ...            ...           ...        ...
# 8517        0  64.0             0              0             0          3
# 12278       0  76.0             0              0             0          0
# 12143       1  13.0             0              1             0          4
# 15726       1  78.0             0              0             1          0
# 15456       1  19.0             0              1             1          2
#
#        Residence_type  avg_glucose_level   bmi  smoking_status
# ...

# %%
data.iloc[2260]
# Out:
# gender                 1.00
# age                   56.00
# hypertension           0.00
# heart_disease          0.00
# ever_married           0.00
# work_type              0.00
# Residence_type         1.00
# avg_glucose_level    156.16
# bmi                   23.50
# smoking_status         1.00
# stroke                 0.00
# Name: 2260, dtype: float64

# %%
Y_test
# Out:
# 17236    1
# 18748    0
# 15002    0
# 13962    0
# 6916     0
#         ..
# 8517     0
# 12278    0
# 12143    0
# 15726    0
# 15456    0
# Name: stroke, Length: 4000, dtype: int64

# %% [markdown]
# # **Normalize**

# %%
data.describe()
# Out:
#              gender           age  hypertension  heart_disease  ever_married  \
# count  19997.000000  19997.000000  19997.000000   19997.000000  19997.000000
# mean       0.648797     45.403911      0.053658       0.252438      0.520228
# std        0.479762     24.710827      0.225347       0.434422      0.499603
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%        0.000000     22.000000      0.000000       0.000000      0.000000
# 50%        1.000000     50.000000      0.000000       0.000000      1.000000
# 75%        1.000000     64.000000      0.000000       1.000000      1.000000
# max        2.000000     82.000000      1.000000       1.000000      1.000000
#
#           work_type  Residence_type  avg_glucose_level           bmi  \
# count  19997.000000    19997.000000       19997.000000  19997.000000
# mean       2.213682        0.381207         114.501801     26.175997
# ...

# %%
data
# Out:
#        gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0           1  19.0             0              1             1          3
# 1           0  22.0             0              1             1          2
# 2           1  49.0             0              0             0          0
# 3           1  21.0             0              1             0          2
# 4           1  23.0             0              0             1          0
# ...       ...   ...           ...            ...           ...        ...
# 19994       0  26.0             0              0             1          2
# 19995       1  58.0             0              0             0          4
# 19996       1  55.0             0              0             0          3
# 19997       0  14.0             0              0             1          3
# 19998       1  58.0             0              0             0          4
#
#        Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
ans = 0
for d in data['hypertension']:

  ans += 1

  if d == 1:

    print(ans)

    break
# Out:
# 23

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()

# %%
data
# Out:
#        gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0           1  19.0             0              1             1          3
# 1           0  22.0             0              1             1          2
# 2           1  49.0             0              0             0          0
# 3           1  21.0             0              1             0          2
# 4           1  23.0             0              0             1          0
# ...       ...   ...           ...            ...           ...        ...
# 19994       0  26.0             0              0             1          2
# 19995       1  58.0             0              0             0          4
# 19996       1  55.0             0              0             0          3
# 19997       0  14.0             0              0             1          3
# 19998       1  58.0             0              0             0          4
#
#        Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
data.iloc[5000]
# Out:
# gender                1.00
# age                  53.00
# hypertension          0.00
# heart_disease         0.00
# ever_married          1.00
# work_type             2.00
# Residence_type        0.00
# avg_glucose_level    98.49
# bmi                  20.40
# smoking_status        2.00
# stroke                0.00
# Name: 5000, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19997 entries, 0 to 19998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             19997 non-null  int64
#  1   age                19997 non-null  float64
#  2   hypertension       19997 non-null  int64
#  3   heart_disease      19997 non-null  int64
#  4   ever_married       19997 non-null  int64
#  5   work_type          19997 non-null  int64
#  6   Residence_type     19997 non-null  int64
#  7   avg_glucose_level  19997 non-null  float64
#  8   bmi                19997 non-null  float64
#  9   smoking_status     19997 non-null  int64
#  10  stroke             19997 non-null  int64
# dtypes: float64(3), int64(8)
# memory usage: 1.8 MB

# %%
# Fit and transform the data
X_train_std=std.fit_transform(X_train)
X_test_std=std.transform(X_test)

# %%
X_train_std=std.fit_transform(X_train)
X_test_std=std.transform(X_test)

# %% [markdown]
# # **lets save the scaler object**

# %%
import pickle
import os
scaler_path=os.path.join('/content/drive/MyDrive','models/scaler.pkl')
with open(scaler_path,'wb') as scaler_file:
    pickle.dump(std,scaler_file)

# %%
X_train_std
# Out:
# array([[-1.34371973, -1.07285073, -0.23497038, ...,  0.86374559,
#         -0.9139593 , -1.46629764],
#        [ 0.73615299, -0.99182706, -0.23497038, ...,  0.74452946,
#          1.16606688,  0.71244687],
#        [-1.34371973, -1.55899275, -0.23497038, ..., -0.29878803,
#         -1.27570298,  0.71244687],
#        ...,
#        [ 0.73615299, -0.14107853, -0.23497038, ..., -0.4485724 ,
#         -1.38121155, -1.46629764],
#        [-1.34371973,  1.23632385, -0.23497038, ..., -1.09332709,
#          0.84954116,  0.71244687],
#        [ 0.73615299, -0.18159037, -0.23497038, ..., -0.06529371,
#         -0.88381399,  0.71244687]])

# %%
X_test_std
# Out:
# array([[-1.34371973, -1.72104008,  4.25585548, ...,  0.73465357,
#          0.20141706,  0.71244687],
#        [ 0.73615299, -0.30312587, -0.23497038, ...,  2.23461352,
#         -0.92903195, -1.46629764],
#        [-1.34371973,  0.50711082, -0.23497038, ..., -1.00162237,
#          0.3822889 ,  0.71244687],
#        ...,
#        [ 0.73615299, -1.31592174, -0.23497038, ..., -0.51229542,
#         -0.02467274, -1.46629764],
#        [ 0.73615299,  1.31734751, -0.23497038, ..., -0.05847465,
#         -0.38641643, -0.37692539],
#        [ 0.73615299, -1.07285073, -0.23497038, ..., -0.6143463 ,
#          1.91969955,  0.71244687]])

# %% [markdown]
# # **Training**

# %%
data
# Out:
#        gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0           1  19.0             0              1             1          3
# 1           0  22.0             0              1             1          2
# 2           1  49.0             0              0             0          0
# 3           1  21.0             0              1             0          2
# 4           1  23.0             0              0             1          0
# ...       ...   ...           ...            ...           ...        ...
# 19994       0  26.0             0              0             1          2
# 19995       1  58.0             0              0             0          4
# 19996       1  55.0             0              0             0          3
# 19997       0  14.0             0              0             1          3
# 19998       1  58.0             0              0             0          4
#
#        Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
print(data.isnull())
# Out:
#        gender    age  hypertension  heart_disease  ever_married  work_type  \
# 0       False  False         False          False         False      False
# 1       False  False         False          False         False      False
# 2       False  False         False          False         False      False
# 3       False  False         False          False         False      False
# 4       False  False         False          False         False      False
# ...       ...    ...           ...            ...           ...        ...
# 19994   False  False         False          False         False      False
# 19995   False  False         False          False         False      False
# 19996   False  False         False          False         False      False
# 19997   False  False         False          False         False      False
# 19998   False  False         False          False         False      False
#
# ...

# %% [markdown]
# # **Decision Tree**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19997 entries, 0 to 19998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             19997 non-null  int64
#  1   age                19997 non-null  float64
#  2   hypertension       19997 non-null  int64
#  3   heart_disease      19997 non-null  int64
#  4   ever_married       19997 non-null  int64
#  5   work_type          19997 non-null  int64
#  6   Residence_type     19997 non-null  int64
#  7   avg_glucose_level  19997 non-null  float64
#  8   bmi                19997 non-null  float64
#  9   smoking_status     19997 non-null  int64
#  10  stroke             19997 non-null  int64
# dtypes: float64(3), int64(8)
# memory usage: 1.8 MB

# %%
data
# Out:
#        gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0           1  19.0             0              1             1          3
# 1           0  22.0             0              1             1          2
# 2           1  49.0             0              0             0          0
# 3           1  21.0             0              1             0          2
# 4           1  23.0             0              0             1          0
# ...       ...   ...           ...            ...           ...        ...
# 19994       0  26.0             0              0             1          2
# 19995       1  58.0             0              0             0          4
# 19996       1  55.0             0              0             0          3
# 19997       0  14.0             0              0             1          3
# 19998       1  58.0             0              0             0          4
#
#        Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
print(data[data.isnull().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train_std,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.feature_importances_
# Out:
# array([0.03116708, 0.17637279, 0.01344124, 0.011235  , 0.01651388,
#        0.0460184 , 0.02931082, 0.37301143, 0.23984776, 0.0630816 ])

# %%
X_train.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status'],
#       dtype='object')

# %%
from joblib import dump
dump(dt,'./dec-tree')
# Out:
# ['./dec-tree']

# %%
x = dt.predict([[1,45,1,1,1,3,1,202.21,1,1]])
print(x)
# Out:
# [1]

# %%
Y_pred=dt.predict(X_test_std)

# %%
Y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
ac_dt=accuracy_score(Y_test,Y_pred)
ac_dt
# Out:
# 0.91475

# %%
import joblib
model_path=os.path.join('/content/drive/MyDrive','models/dt.sav')
joblib.dump(dt,model_path)
# Out:
# ['/content/drive/MyDrive/models/dt.sav']

# %% [markdown]
# # **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(X_train_std,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred_lr=lr.predict(X_test_std)

# %%
Y_pred_lr
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
ac_lr=accuracy_score(Y_test,Y_pred_lr)

# %%
ac_lr
# Out:
# 0.92275

# %%
from joblib import dump
dump(lr,'./logistic-reg')
# Out:
# ['./logistic-reg']

# %% [markdown]
# # **KNN**

# %% [markdown]
# logistic regression = 93.835
# Kth nearest neighbour = 93.444
# Decision Tree = 90.019

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(X_train_std,Y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred=knn.predict(X_test_std)

# %%
ac_knn=accuracy_score(Y_test,Y_pred)

# %%
ac_knn
# Out:
# 0.91625

# %%
from joblib import dump
dump(knn,'./knn')
# Out:
# ['./knn']

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(X_train_std,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred=rf.predict(X_test_std)

# %%
ac_rf=accuracy_score(Y_test,Y_pred)

# %%
ac_rf
# Out:
# 0.963

# %%
ac_knn
# Out:
# 0.91625

# %%
ac_lr
# Out:
# 0.92275

# %%
from joblib import dump
dump(rf,'./random-forest')
# Out:
# ['./random-forest']

# %% [markdown]
# # **SVM**

# %% [markdown]
# Random forest = 93.835
# SVM = 93.933

# %%
from sklearn.svm import SVC

# %%
sv=SVC()

# %%
sv.fit(X_train_std,Y_train)
# Out:
# SVC()

# %%
Y_pred=sv.predict(X_test_std)

# %%
ac_sv=accuracy_score(Y_test,Y_pred)

# %%
ac_sv
# Out:
# 0.92275

# %%
ac_lr
# Out:
# 0.92275

# %%
from joblib import dump
dump(sv,'./svm')
# Out:
# ['./svm']

# %%
plt.bar(['Decision Tree','Logistic','KNN','Random Forest','SVM'],[ac_dt,ac_lr,ac_knn,ac_rf,ac_sv])
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# logistic regression = 93.835
# Kth nearest neighbour = 93.444
# Decision Tree = 90.019
# Random forest = 93.835
# SVM = 93.933
